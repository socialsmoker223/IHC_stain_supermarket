# %%
import requests
import io
import pandas as pd
import json

# %%
def run(csv):
    
    url = 'http://127.0.0.1:8000/train_rules'
    files = {"file": open(csv, 'rb')}
    r = requests.post(url, files=files)
    data = r.text
    df = pd.DataFrame(json.loads(data)['df'])
    return df

# %%
df = run('./data/ihc_record.csv')
df
# Out:
#              antecedents      consequents  antecedent support  \
# 0              [C-ERBB2]             [ER]            0.018588
# 1              [C-ERBB2]             [PR]            0.018588
# 2                [CD138]          [KAPPA]            0.013583
# 3                [CD138]         [LAMBDA]            0.013583
# 4                 [CD21]           [CD20]            0.017155
# ..                   ...              ...                 ...
# 103      [PAS, ZNX2, WF]        [GROCOTT]            0.015900
# 104   [PAS, GROCOTT, WF]           [ZNX2]            0.015245
# 105  [ZNX2, GROCOTT, WF]            [PAS]            0.016713
# 106            [PAS, WF]  [ZNX2, GROCOTT]            0.016165
# 107        [GROCOTT, WF]      [PAS, ZNX2]            0.017032
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.048919  0.016678    0.897241  18.341209  0.015769    9.255423
# ...
